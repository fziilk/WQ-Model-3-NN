# %% [markdown]
# <a href="https://colab.research.google.com/github/fziilk/WQ-Model-3-NN/blob/master/EVAL_MODEL3_NN_WQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files
from keras.models import load_model
import joblib

# %%
files.upload()
# Out:
#      <input type="file" id="files-5e089315-56ca-4674-9c1c-498db4ee414d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e089315-56ca-4674-9c1c-498db4ee414d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model_alpha = load_model("/content/model3_{'units1'_ 256, 'units2'_ 32, 'dropout'_ 0.2, 'l2'_ 0.001, 'lr'_ 0.001}-0.7128712871287128.keras")

# %%
HASIL_KERAN = {
    'ph': 6.5,
    'Kesadahan': 88.8,
    'TDS': 320,
    'Sulfat': 14,
    'Konduktivitas': 466,
    'Kekeruhan': 0.15
}

HASIL_MINUM = {
    'ph':[6.3],
    'Kesadahan': [50.4],
    'TDS': [67.3],
    'Sulfat': [4.7],
    'Konduktivitas': [130.4],
    'Kekeruhan': [0.09]
}

# %%
x1 = pd.DataFrame(HASIL_KERAN, index=[0])
x2 = pd.DataFrame(HASIL_MINUM, index=[0])

# %%
files.upload()
# Out:
#      <input type="file" id="files-df50a279-35e3-45a4-92e7-1df4a1139f96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df50a279-35e3-45a4-92e7-1df4a1139f96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
scaler = joblib.load('/content/scaler.pkl')

x1_scaled = scaler.transform(x1)
x2_scaled = scaler.transform(x2)

# %%
x1_scaled = scaler.transform(x1)
x2_scaled = scaler.transform(x2)

# %%
x1
# Out:
#     ph  Kesadahan  TDS  Sulfat  Konduktivitas  Kekeruhan
# 0  6.5       88.8  320      14            466       0.15

# %%
x2
# Out:
#     ph  Kesadahan   TDS  Sulfat  Konduktivitas  Kekeruhan
# 0  6.3       50.4  67.3     4.7          130.4       0.09

# %%
print(x1_scaled)
print(x2_scaled)
# Out:
# [[-0.34991648 -3.30519868 -2.46449139 -7.88977884  0.49639252 -4.96699682]]
# [[-0.474508   -4.48928765 -2.49344497 -8.11895089 -3.65337158 -5.04497068]]

# %%
y_x1 = (model_alpha.predict(x1_scaled) > 0.5).astype(int)
y_x2 = (model_alpha.predict(x2_scaled) > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
if y_x1[-1][-1] == 1:
    Y_RES = 'potable'
else:
    Y_RES = 'not potable'

print(f'Prediksi Model 3 NN (Kelas KERAN_MASJID): {Y_RES}')
# Out:
# Prediksi Model 3 NN (Kelas KERAN_MASJID): not potable

# %%
if y_x2[-1][-1] == 1:
    Y_RES = 'potable'
else:
    Y_RES = 'not potable'

print(f'Prediksi Model 3 NN (Kelas AIR_MINUM): {Y_RES}')
# Out:
# Prediksi Model 3 NN (Kelas AIR_MINUM): potable
